# %%
from gevent import monkey
monkey.patch_all()

import os
import requests
import grequests
from bs4 import BeautifulSoup
from fake_useragent import UserAgent
import json
import logging
import time


class Article:
    """
    Class Article holds information about a news article from Nasdaq.com/markets.
    Information includes: id, title, authors, date, and tags.
    """
    def __init__(self, id_num, url, headers):
        self.id_num = id_num
        self.url = url
        self._headers = headers
        self.title = self._get_title()
        self.authors = self._get_authors()
        self.date = self._get_date()
        self.tage = self._get_tags()
        
        
        
    def _get_soup(self, conent):
        """
        Parses the HTML content and returns a soup object.
        """
        return BeautifulSoup(content, "html.parser")
        
    def _get_title(self, soup):
        """
        Returns the name of the title of the article from the soup object.
        """
#         title = ? YOUR CODE HERE JHONNY
        return title

    def get_title(self)
        """
        Returns article's title.
        """
        return self.title


    def _get_authors(self, soup):
        """
        Returns the names of the authors of the article from the soup object.
        """
#         authors = ? YOUR CODE HERE JHONNY
        return authors

  def get_authors(self):
        """
        Returns article's authors.
        """
        return self.authors

    def _get_date(self, soup):
        """
        Returns the date of the article from the soup object.
        """
#         date = ? YOUR CODE HERE JHONNY
        return date

    def get_date(self, soup):
        """
        Returns article's date.
        """
        return self.date

    def _get_tags(self, soup):
        """
        Returns the tags of the article from the soup object.
        """
        tags = []
#         tags = ? YOUR CODE HERE JHONNY
        return tags

    def get_tags(self):
        """
        Returns article's tags.
        """
        return self.tags
    
    def _create_article_content_file(self, content):
        """
        Creates a text file containing the article content in a subfolder 
        """
        # The plan is to take the content in this function instead of making another conent.
        if not os.path.isdir("article content files"): # Creats the folder if it doesn't exist.
            os.mkdir("article content files")
            
        with open(f'{self.id}.txt' , 'w') as f: # The file will have the id name.
            f.write(content)
# Out:
#   File "<tokenize>", line 57
#     def get_authors(self)
#     ^
# IndentationError: unindent does not match any outer indentation level
